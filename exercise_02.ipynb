# %% [markdown]
# # 🏁 Launching a Crew
#
# Now that we have our Research Agent created, we need to create a Task for the agent to accomplish and equip it with the WebsiteSearch Tool for it to search the web.
#
# A task is like a work assignment with:
#
# - 📝 a Description: clear instructions on what to do;
# - 🧾 an Expected Output: what the final deliverable should look like;
# - 🔧 any Tools: the resources available to complete the task.

# %% [markdown]
# <img src="images/agent_diagram.jpg" width="700" alt="Diagram of CrewAI components">

# %% [markdown]
# ### ❗️ Note: Run the **hidden cells** below before running the rest of the code. ❗️

# %%
import sys, subprocess
subprocess.run([sys.executable, "-m", "pip", "install", "-U",
                "crewai==0.157.0", "crewai_tools==0.58.0"],
               check=True)
# Out:
# ...
#   Using cached langchain_community-0.3.31-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached langchain_core-0.3.83-py3-none-any.whl.metadata (3.2 kB)
# ...
#   Using cached langchain_text_splitters-0.3.11-py3-none-any.whl.metadata (1.8 kB)
# ...
# Using cached langchain_community-0.3.31-py3-none-any.whl (2.5 MB)
# Using cached langchain_core-0.3.83-py3-none-any.whl (458 kB)
# Using cached langchain_text_splitters-0.3.11-py3-none-any.whl (33 kB)
# ...
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.2.14
#     Uninstalling langchain-core-1.2.14:
#       Successfully uninstalled langchain-core-1.2.14
#   Attempting uninstall: langchain-text-splitters 0/3 [langchain-core]
#     Found existing installation: langchain-text-splitters 1.1.1langchain-core]
#     Uninstalling langchain-text-splitters-1.1.1: 0/3 [langchain-core]
#       Successfully uninstalled langchain-text-splitters-1.1.1 [langchain-core]
# ...

# %%
import sys, subprocess
subprocess.run([sys.executable, "-m", "pip", "install", "-U",
                "ddgs", "duckduckgo-search", "langchain-community"],
               check=True)
# Out:
# ...
#   Using cached langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached langchain_core-1.2.14-py3-none-any.whl.metadata (4.4 kB)
# ...
#   Using cached langchain_text_splitters-1.1.1-py3-none-any.whl.metadata (3.3 kB)
# ...
# Using cached langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
# Using cached langchain_core-1.2.14-py3-none-any.whl (501 kB)
# Using cached langchain_text_splitters-1.1.1-py3-none-any.whl (35 kB)
# ...
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.83
#     Uninstalling langchain-core-0.3.83:
#       Successfully uninstalled langchain-core-0.3.83
#   Attempting uninstall: langchain-text-splitters 0/3 [langchain-core]
#     Found existing installation: langchain-text-splitters 0.3.11angchain-core]
#     Uninstalling langchain-text-splitters-0.3.11:0/3 [langchain-core]
#       Successfully uninstalled langchain-text-splitters-0.3.11[langchain-core]
# ...

# %%
from langchain_openai import ChatOpenAI
from langchain_community.tools import DuckDuckGoSearchRun
from crewai import Agent, LLM
from crewai.tools import tool

# Configure OpenAI LLM to be used by the agents
AGENT_LLM = LLM(model="openai/gpt-4o-mini", temperature=0, max_tokens=250, request_timeout=10)

# Initialize the search tool
search_tool_instance = DuckDuckGoSearchRun(k=3)

# Wrap the langchain tool with the CrewAI @tool decorator
@tool("DuckDuckGo Search")
def search_tool(query: str) -> str:
    """A tool for searching the web using DuckDuckGo."""
    return search_tool_instance.run(query)
  
# Define the agent
research_agent = Agent(
  role="Senior Research Analyst",
  goal="Analyze the content of the provided website and extract key insights.",
  backstory="""You are a world-class research analyst with a knack for identifying
  the most important trends and data points from any text. You have a keen eye for detail
  and are known for your concise and insightful summaries.""",
  verbose=False,
  llm=AGENT_LLM,
  tools=[search_tool],
  allow_delegation=False
)

# %%
from crewai import Task

# CODE: Create a research task
research_task = Task(
    description="""Research the latest developments in AI agent technology in 2025.
    Focus on:
    1. Key breakthroughs and innovations
    2. Major companies and their contributions
    3. Practical applications and use cases
    4. Future trends and predictions

    Provide a comprehensive analysis that a business executive could use for strategic planning.""",
    expected_output="A detailed research report with key insights, trends, and actionable recommendations about AI agent technology developments in 2025.",
    agent=research_agent
)

print("✅ Research Task Created!")
print(f"Description: {research_task.description[:100]}...")
# Out:
# ✅ Research Task Created!
# Description: Research the latest developments in AI agent technology in 2025.
#     Focus on:
#     1. Key breakthrou...

# %% [markdown]
# ### 🚀 Assembling and launching your researcher
#
# Combine agent and task into a Crew, run it, and view the initial research output.
#
# A Crew coordinates agents and tasks:
# - **Agents**: the team members with different roles
# - **Tasks**: the work to be completed
# - **Process**: how tasks are executed (sequential by default)

# %%
from crewai import Crew, Process

# CODE: Assemble your research crew
research_crew = Crew(
    agents=[research_agent],
    tasks=[research_task],
    process=Process.sequential,
    verbose=False
)

# CODE: Kickoff the crew and get results
print("🚀 Launching Research Crew...")
research_result = research_crew.kickoff()

from IPython.display import Markdown
print("\n" + "="*50)
print("📊 RESEARCH REPORT COMPLETE")
print("="*50)
Markdown(research_result.raw)
# Out:
# 🚀 Launching Research Crew...
#  Maximum iterations reached. Requesting final answer.
#
# ...
# 📊 RESEARCH REPORT COMPLETE
# ...
# In 2025, AI agent technology has seen significant advancements characterized by key breakthroughs, contributions from major companies, practical applications, and emerging trends.
#
# 1. **Key Breakthroughs and Innovations**:
#    - The development of more sophisticated AI agents capable of understanding and processing natural language has led to enhanced user interactions. These agents can now perform complex tasks autonomously, leveraging advancements in machine learning and natural language processing.
#    - Multi-agent systems have emerged, allowing different AI agents to collaborate on tasks, improving efficiency and scalability in various applications.
#
# 2. **Major Companies and Their Contributions**:
# ...

# %% [markdown]
# ### 📌 Roles, models, and applications of crews
#
# Here are some key takeaways from Crews and their applications:
#
#   - **Role & task definitions** shape writing style and tone.
#   - **Model choice** impacts quality, depth, and style of generated insights.
#   - **Adaptability** allows applying the setup to diverse use cases.
